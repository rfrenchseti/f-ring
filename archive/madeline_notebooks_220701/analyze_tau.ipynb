# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
if '..' not in sys.path: sys.path.append('..')
from f_ring_util import (compute_corrected_ew, 
                         fit_hg_phase_function, 
                         hg_func,
                         print_hg_params)
import argparse

# %%
#Set values of radii, region based on user-given values
parser = argparse.ArgumentParser()

parser.add_argument('-region', help='core, inner, or outer', required=False)
parser.add_argument('-rin', help='inner radius value', required=False)
parser.add_argument('-rout',help='outer radius value', required=False)

test_region = 'core'
test_rin = '139220'
test_rout= '141220'

args = parser.parse_args(args=[])

if args.region:
    region = args.region
else:
    region = test_region
if args.rin:
    rin = str(args.rin)
else:
    rin = test_rin
if args.rout:
    rout= str(args.rout)
else:
    rout= test_rout

# %%
# Set the filepath for the csv to read in based on parameters

size = '0' #slice/step size of the csv file, currently only have 0
dump_ew_dir = '/Users/mlessard/REU_2022/data/dump_ew_csv/'

filepath = dump_ew_dir+region+'/rin'+rin+'_rout'+rout+'/slice'+size+'_ew_stats.csv'

#set value to cut off EQX observations 
eqx_cutoff = 1.5

# %%
# Read the data and dump statistics

orig_obsdata = pd.read_csv(filepath, parse_dates=['Date']); ms=20; alpha=0.7
# orig_obsdata = pd.read_csv(filepath, parse_dates=['Date']); ms=4; alpha=0.1
#orig_obsdata = pd.read_csv('../data_files/good_qual_full.csv', parse_dates=['Date']); ms=20; alpha=0.7
# orig_obsdata = pd.read_csv('../data_files/good_qual_1deg.csv', parse_dates=['Date']); ms=4; alpha=0.1
print('** SUMMARY STATISTICS **')
print('Unique observation names:', len(orig_obsdata.groupby('Observation')))
print('Total slices:', len(orig_obsdata))
print('Starting date:', orig_obsdata['Date'].min())
print('Ending date:', orig_obsdata['Date'].max())
print('Time span:', orig_obsdata['Date'].max()-orig_obsdata['Date'].min())

good_i = np.abs(orig_obsdata['Incidence']-90) > eqx_cutoff
obsdata = orig_obsdata[good_i]
print('Removed OBSIDs:', set(orig_obsdata[~good_i].groupby('Observation').indices))
print('Final unique observation names:', len(obsdata))
# Out:
# ** SUMMARY STATISTICS **
# Unique observation names: 148
# Total slices: 148
# Starting date: 2004-06-20 20:03:28
# Ending date: 2017-09-06 11:47:07
# Time span: 4825 days 15:43:39
# Removed OBSIDs: {'ISS_111RF_FMOVIE002_PRIME', 'ISS_112RF_FMOVIE002_PRIME_2', 'ISS_115RF_FMOVIEEQX001_PRIME', 'ISS_114RF_FMOVIEEQX001_PRIME', 'ISS_112RF_FMOVIE002_PRIME_1', 'ISS_110RF_FMOVIE002_PRIME'}
# Final unique observation names: 142

# %% [markdown]
# # Optimize Tau for Low-Phase Observations

# %%
# Find "small" (<6) e or i

low_phase_mask = obsdata['Mean Phase'] <= 60
low_phase_obsdata = obsdata[low_phase_mask]
lp_low_e_mask = np.abs(low_phase_obsdata['Mean Emission']-90) < 6
lp_low_i_mask = np.abs(low_phase_obsdata['Incidence']-90) < 6
lp_low_ei_mask = lp_low_e_mask | lp_low_i_mask

low_e_mask = np.abs(obsdata['Mean Emission']-90) < 6
low_i_mask = np.abs(obsdata['Incidence']-90) < 6
low_ei_mask = low_e_mask | low_i_mask

# %%
# Find the optimal tau to minimize scatter

best_tau = None
best_ratio = 1e38
for tau in np.arange(0.000, 0.101, 0.001):
    corrected_ew = compute_corrected_ew(low_phase_obsdata['Normal EW'], 
                                        low_phase_obsdata['Mean Emission'], 
                                        low_phase_obsdata['Incidence'], 
                                        tau=tau)
    mean_low = np.mean(corrected_ew[lp_low_ei_mask])
    mean_notlow = np.mean(corrected_ew[~lp_low_ei_mask])
    if abs(mean_notlow/mean_low-1) < best_ratio:
        best_ratio = abs(mean_notlow/mean_low-1)
        best_tau = tau
    if abs(mean_low/mean_notlow-1) < best_ratio:
        best_ratio = abs(mean_low/mean_notlow-1)
        best_tau = tau
    print(f'Tau {tau:.3f} - Mean Normal EW Low E/I: {mean_low:8.5f} '
          f'EW Other: {mean_notlow:8.5f} '
          f'Ratio: {mean_notlow/mean_low:5.3f}')
    
print()
print(f'** Best Tau: {best_tau:.3f}')

print()
print('Uncorrected Low Phase:')
uc_mean_low = np.mean(low_phase_obsdata['Normal EW'][lp_low_ei_mask])
uc_mean_notlow = np.mean(low_phase_obsdata['Normal EW'][~lp_low_ei_mask])
print(f'Mean Normal EW Low E/I: {uc_mean_low:.5f}')
print(f'Mean Normal EW Other:   {uc_mean_notlow:.5f}')
print(f'Other/Low: {uc_mean_notlow/uc_mean_low:.5f}')
print()

lp_corrected_ew = compute_corrected_ew(low_phase_obsdata['Normal EW'], 
                                       low_phase_obsdata['Mean Emission'], 
                                       low_phase_obsdata['Incidence'], 
                                       tau=best_tau)
mean_low = np.mean(lp_corrected_ew[lp_low_ei_mask])
mean_notlow = np.mean(lp_corrected_ew[~lp_low_ei_mask])
print(f'Corrected (tau={best_tau:.3f}) Low Phase:')
print(f'Mean Normal EW Low E/I: {mean_low:.5f}')
print(f'Mean Normal EW Other:   {mean_notlow:.5f}')
print(f'Other/Low: {mean_notlow/mean_low:.5f}')

print()
print('Overall change due to Tau:')
print(f'Mean Normal EW Low E/I: {mean_low/uc_mean_low:.5f}')
print(f'Mean Normal EW Other:   {mean_notlow/uc_mean_notlow:.5f}')


# Find H-G phase curve for full dataset
corrected_ew = compute_corrected_ew(obsdata['Normal EW'], 
                                    obsdata['Mean Emission'], 
                                    obsdata['Incidence'], 
                                    tau=best_tau)

uc_hg_params, uc_hg_used_data, uc_hg_std = fit_hg_phase_function(2, None, obsdata, 
                                                                 verbose=False)
print()
print('Uncorrected H-G params:')
print_hg_params(uc_hg_params, indent=2)
print(f'  Standard deviation: {uc_hg_std:.5f}')

hg_params, hg_used_data, hg_std = fit_hg_phase_function(2, None, obsdata, 
                                                        tau=best_tau,
                                                        verbose=False)
print()
print(f'Corrected (tau={best_tau:.3f}) params:')
print_hg_params(hg_params, indent=2)
print(f'  Standard deviation: {hg_std:.5f}')

# Plot results
plt.figure(figsize=(12,9))
plt.subplot(2, 2, 1)
plt.scatter(low_phase_obsdata['Mean Phase'][lp_low_ei_mask], 
            low_phase_obsdata['Normal EW'][lp_low_ei_mask], 
            s=ms, c='red', label='Low e or i')
plt.scatter(low_phase_obsdata['Mean Phase'][~lp_low_ei_mask], 
            low_phase_obsdata['Normal EW'][~lp_low_ei_mask], 
            s=ms, alpha=alpha, c='blue', label='Other')
plt.legend()
plt.xlabel('Phase Angle (°)')
plt.ylabel('Normal EW')
plt.title('Normal EW vs. Phase Angle (uncorrected)')

plt.subplot(2, 2, 2)
plt.scatter(low_phase_obsdata['Mean Phase'][lp_low_ei_mask], 
            lp_corrected_ew[lp_low_ei_mask], 
            s=ms, c='red', label='Low e or i')
plt.scatter(low_phase_obsdata['Mean Phase'][~lp_low_ei_mask], 
            lp_corrected_ew[~lp_low_ei_mask], 
            s=ms, alpha=alpha, c='blue', label='Other')
plt.legend()
plt.xlabel('Phase Angle (°)')
plt.ylabel('Normal EW')
plt.title(f'Normal EW vs. Phase Angle (tau={best_tau:.3f})')

plt.subplot(2, 2, 3)
plt.scatter(obsdata['Mean Phase'][low_ei_mask], 
            obsdata['Normal EW'][low_ei_mask], 
            s=ms, c='red', label='Low e or i')
plt.scatter(obsdata['Mean Phase'][~low_ei_mask], 
            obsdata['Normal EW'][~low_ei_mask], 
            s=ms, alpha=alpha, c='blue', label='Other')
xrange = np.arange(obsdata['Mean Phase'].min(), obsdata['Mean Phase'].max()+1)
uc_hg_phase_model = hg_func(uc_hg_params, np.radians(xrange))
plt.plot(xrange, uc_hg_phase_model, '-', color='green', lw=2, label='Phase model')
plt.legend()
plt.xlabel('Phase Angle (°)')
plt.ylabel('Normal EW')
plt.title('Normal EW vs. Phase Angle (uncorrected)')

plt.subplot(2, 2, 4)
plt.scatter(obsdata['Mean Phase'][low_ei_mask], 
            corrected_ew[low_ei_mask], 
            s=ms, c='red', label='Low e or i')
plt.scatter(obsdata['Mean Phase'][~low_ei_mask], 
            corrected_ew[~low_ei_mask], 
            s=ms, alpha=alpha, c='blue', label='Other')
xrange = np.arange(obsdata['Mean Phase'].min(), obsdata['Mean Phase'].max()+1)
hg_phase_model = hg_func(hg_params, np.radians(xrange))
plt.plot(xrange, hg_phase_model, '-', color='green', lw=2, label='Phase model')
plt.legend()
plt.xlabel('Phase Angle (°)')
plt.ylabel('Normal EW')
plt.title(f'Normal EW vs. Phase Angle (tau={best_tau:.3f})')
plt.show()
# Out:
# Tau 0.000 - Mean Normal EW Low E/I:  0.52976 EW Other:  0.59054 Ratio: 1.115
# Tau 0.001 - Mean Normal EW Low E/I:  0.53415 EW Other:  0.59250 Ratio: 1.109
# Tau 0.002 - Mean Normal EW Low E/I:  0.53856 EW Other:  0.59446 Ratio: 1.104
# Tau 0.003 - Mean Normal EW Low E/I:  0.54301 EW Other:  0.59643 Ratio: 1.098
# Tau 0.004 - Mean Normal EW Low E/I:  0.54748 EW Other:  0.59840 Ratio: 1.093
# Tau 0.005 - Mean Normal EW Low E/I:  0.55199 EW Other:  0.60038 Ratio: 1.088
# Tau 0.006 - Mean Normal EW Low E/I:  0.55653 EW Other:  0.60237 Ratio: 1.082
# Tau 0.007 - Mean Normal EW Low E/I:  0.56110 EW Other:  0.60436 Ratio: 1.077
# Tau 0.008 - Mean Normal EW Low E/I:  0.56570 EW Other:  0.60636 Ratio: 1.072
# Tau 0.009 - Mean Normal EW Low E/I:  0.57034 EW Other:  0.60836 Ratio: 1.067
# Tau 0.010 - Mean Normal EW Low E/I:  0.57500 EW Other:  0.61038 Ratio: 1.062
# Tau 0.011 - Mean Normal EW Low E/I:  0.57970 EW Other:  0.61239 Ratio: 1.056
# Tau 0.012 - Mean Normal EW Low E/I:  0.58443 EW Other:  0.61442 Ratio: 1.051
# Tau 0.013 - Mean Normal EW Low E/I:  0.58919 EW Other:  0.61645 Ratio: 1.046
# Tau 0.014 - Mean Normal EW Low E/I:  0.59399 EW Other:  0.61849 Ratio: 1.041
# Tau 0.015 - Mean Normal EW Low E/I:  0.59881 EW Other:  0.62053 Ratio: 1.036
# Tau 0.016 - Mean Normal EW Low E/I:  0.60367 EW Other:  0.62258 Ratio: 1.031
# Tau 0.017 - Mean Normal EW Low E/I:  0.60857 EW Other:  0.62464 Ratio: 1.026
# Tau 0.018 - Mean Normal EW Low E/I:  0.61349 EW Other:  0.62670 Ratio: 1.022
# Tau 0.019 - Mean Normal EW Low E/I:  0.61845 EW Other:  0.62878 Ratio: 1.017
# Tau 0.020 - Mean Normal EW Low E/I:  0.62344 EW Other:  0.63085 Ratio: 1.012
# Tau 0.021 - Mean Normal EW Low E/I:  0.62847 EW Other:  0.63294 Ratio: 1.007
# Tau 0.022 - Mean Normal EW Low E/I:  0.63352 EW Other:  0.63503 Ratio: 1.002
# Tau 0.023 - Mean Normal EW Low E/I:  0.63862 EW Other:  0.63712 Ratio: 0.998
# Tau 0.024 - Mean Normal EW Low E/I:  0.64374 EW Other:  0.63923 Ratio: 0.993
# Tau 0.025 - Mean Normal EW Low E/I:  0.64890 EW Other:  0.64134 Ratio: 0.988
# Tau 0.026 - Mean Normal EW Low E/I:  0.65409 EW Other:  0.64346 Ratio: 0.984
# Tau 0.027 - Mean Normal EW Low E/I:  0.65932 EW Other:  0.64558 Ratio: 0.979
# Tau 0.028 - Mean Normal EW Low E/I:  0.66458 EW Other:  0.64771 Ratio: 0.975
# Tau 0.029 - Mean Normal EW Low E/I:  0.66988 EW Other:  0.64985 Ratio: 0.970
# Tau 0.030 - Mean Normal EW Low E/I:  0.67521 EW Other:  0.65199 Ratio: 0.966
# Tau 0.031 - Mean Normal EW Low E/I:  0.68057 EW Other:  0.65414 Ratio: 0.961
# Tau 0.032 - Mean Normal EW Low E/I:  0.68597 EW Other:  0.65630 Ratio: 0.957
# Tau 0.033 - Mean Normal EW Low E/I:  0.69140 EW Other:  0.65847 Ratio: 0.952
# Tau 0.034 - Mean Normal EW Low E/I:  0.69687 EW Other:  0.66064 Ratio: 0.948
# Tau 0.035 - Mean Normal EW Low E/I:  0.70237 EW Other:  0.66282 Ratio: 0.944
# Tau 0.036 - Mean Normal EW Low E/I:  0.70791 EW Other:  0.66500 Ratio: 0.939
# Tau 0.037 - Mean Normal EW Low E/I:  0.71349 EW Other:  0.66720 Ratio: 0.935
# Tau 0.038 - Mean Normal EW Low E/I:  0.71910 EW Other:  0.66939 Ratio: 0.931
# Tau 0.039 - Mean Normal EW Low E/I:  0.72474 EW Other:  0.67160 Ratio: 0.927
# Tau 0.040 - Mean Normal EW Low E/I:  0.73042 EW Other:  0.67381 Ratio: 0.923
# Tau 0.041 - Mean Normal EW Low E/I:  0.73614 EW Other:  0.67603 Ratio: 0.918
# Tau 0.042 - Mean Normal EW Low E/I:  0.74189 EW Other:  0.67826 Ratio: 0.914
# Tau 0.043 - Mean Normal EW Low E/I:  0.74768 EW Other:  0.68050 Ratio: 0.910
# Tau 0.044 - Mean Normal EW Low E/I:  0.75350 EW Other:  0.68274 Ratio: 0.906
# Tau 0.045 - Mean Normal EW Low E/I:  0.75936 EW Other:  0.68499 Ratio: 0.902
# Tau 0.046 - Mean Normal EW Low E/I:  0.76526 EW Other:  0.68724 Ratio: 0.898
# Tau 0.047 - Mean Normal EW Low E/I:  0.77119 EW Other:  0.68950 Ratio: 0.894
# Tau 0.048 - Mean Normal EW Low E/I:  0.77716 EW Other:  0.69177 Ratio: 0.890
# Tau 0.049 - Mean Normal EW Low E/I:  0.78317 EW Other:  0.69405 Ratio: 0.886
# Tau 0.050 - Mean Normal EW Low E/I:  0.78921 EW Other:  0.69633 Ratio: 0.882
# Tau 0.051 - Mean Normal EW Low E/I:  0.79529 EW Other:  0.69862 Ratio: 0.878
# Tau 0.052 - Mean Normal EW Low E/I:  0.80141 EW Other:  0.70092 Ratio: 0.875
# Tau 0.053 - Mean Normal EW Low E/I:  0.80756 EW Other:  0.70323 Ratio: 0.871
# Tau 0.054 - Mean Normal EW Low E/I:  0.81375 EW Other:  0.70554 Ratio: 0.867
# Tau 0.055 - Mean Normal EW Low E/I:  0.81998 EW Other:  0.70786 Ratio: 0.863
# Tau 0.056 - Mean Normal EW Low E/I:  0.82625 EW Other:  0.71019 Ratio: 0.860
# Tau 0.057 - Mean Normal EW Low E/I:  0.83255 EW Other:  0.71252 Ratio: 0.856
# Tau 0.058 - Mean Normal EW Low E/I:  0.83889 EW Other:  0.71486 Ratio: 0.852
# Tau 0.059 - Mean Normal EW Low E/I:  0.84527 EW Other:  0.71721 Ratio: 0.849
# Tau 0.060 - Mean Normal EW Low E/I:  0.85169 EW Other:  0.71957 Ratio: 0.845
# Tau 0.061 - Mean Normal EW Low E/I:  0.85814 EW Other:  0.72193 Ratio: 0.841
# Tau 0.062 - Mean Normal EW Low E/I:  0.86464 EW Other:  0.72430 Ratio: 0.838
# Tau 0.063 - Mean Normal EW Low E/I:  0.87117 EW Other:  0.72668 Ratio: 0.834
# Tau 0.064 - Mean Normal EW Low E/I:  0.87774 EW Other:  0.72907 Ratio: 0.831
# Tau 0.065 - Mean Normal EW Low E/I:  0.88435 EW Other:  0.73146 Ratio: 0.827
# Tau 0.066 - Mean Normal EW Low E/I:  0.89100 EW Other:  0.73386 Ratio: 0.824
# Tau 0.067 - Mean Normal EW Low E/I:  0.89768 EW Other:  0.73627 Ratio: 0.820
# Tau 0.068 - Mean Normal EW Low E/I:  0.90441 EW Other:  0.73869 Ratio: 0.817
# Tau 0.069 - Mean Normal EW Low E/I:  0.91117 EW Other:  0.74111 Ratio: 0.813
# Tau 0.070 - Mean Normal EW Low E/I:  0.91798 EW Other:  0.74354 Ratio: 0.810
# Tau 0.071 - Mean Normal EW Low E/I:  0.92482 EW Other:  0.74598 Ratio: 0.807
# Tau 0.072 - Mean Normal EW Low E/I:  0.93170 EW Other:  0.74842 Ratio: 0.803
# Tau 0.073 - Mean Normal EW Low E/I:  0.93862 EW Other:  0.75088 Ratio: 0.800
# Tau 0.074 - Mean Normal EW Low E/I:  0.94559 EW Other:  0.75334 Ratio: 0.797
# Tau 0.075 - Mean Normal EW Low E/I:  0.95259 EW Other:  0.75581 Ratio: 0.793
# Tau 0.076 - Mean Normal EW Low E/I:  0.95963 EW Other:  0.75828 Ratio: 0.790
# Tau 0.077 - Mean Normal EW Low E/I:  0.96671 EW Other:  0.76077 Ratio: 0.787
# Tau 0.078 - Mean Normal EW Low E/I:  0.97383 EW Other:  0.76326 Ratio: 0.784
# Tau 0.079 - Mean Normal EW Low E/I:  0.98099 EW Other:  0.76576 Ratio: 0.781
# Tau 0.080 - Mean Normal EW Low E/I:  0.98819 EW Other:  0.76827 Ratio: 0.777
# Tau 0.081 - Mean Normal EW Low E/I:  0.99544 EW Other:  0.77078 Ratio: 0.774
# Tau 0.082 - Mean Normal EW Low E/I:  1.00272 EW Other:  0.77330 Ratio: 0.771
# Tau 0.083 - Mean Normal EW Low E/I:  1.01004 EW Other:  0.77583 Ratio: 0.768
# Tau 0.084 - Mean Normal EW Low E/I:  1.01741 EW Other:  0.77837 Ratio: 0.765
# Tau 0.085 - Mean Normal EW Low E/I:  1.02481 EW Other:  0.78092 Ratio: 0.762
# Tau 0.086 - Mean Normal EW Low E/I:  1.03226 EW Other:  0.78347 Ratio: 0.759
# Tau 0.087 - Mean Normal EW Low E/I:  1.03975 EW Other:  0.78603 Ratio: 0.756
# Tau 0.088 - Mean Normal EW Low E/I:  1.04727 EW Other:  0.78860 Ratio: 0.753
# Tau 0.089 - Mean Normal EW Low E/I:  1.05485 EW Other:  0.79118 Ratio: 0.750
# Tau 0.090 - Mean Normal EW Low E/I:  1.06246 EW Other:  0.79376 Ratio: 0.747
# Tau 0.091 - Mean Normal EW Low E/I:  1.07011 EW Other:  0.79636 Ratio: 0.744
# Tau 0.092 - Mean Normal EW Low E/I:  1.07781 EW Other:  0.79896 Ratio: 0.741
# Tau 0.093 - Mean Normal EW Low E/I:  1.08554 EW Other:  0.80157 Ratio: 0.738
# Tau 0.094 - Mean Normal EW Low E/I:  1.09332 EW Other:  0.80419 Ratio: 0.736
# Tau 0.095 - Mean Normal EW Low E/I:  1.10114 EW Other:  0.80681 Ratio: 0.733
# Tau 0.096 - Mean Normal EW Low E/I:  1.10901 EW Other:  0.80944 Ratio: 0.730
# Tau 0.097 - Mean Normal EW Low E/I:  1.11692 EW Other:  0.81209 Ratio: 0.727
# Tau 0.098 - Mean Normal EW Low E/I:  1.12486 EW Other:  0.81474 Ratio: 0.724
# Tau 0.099 - Mean Normal EW Low E/I:  1.13286 EW Other:  0.81739 Ratio: 0.722
# Tau 0.100 - Mean Normal EW Low E/I:  1.14089 EW Other:  0.82006 Ratio: 0.719
#
# ** Best Tau: 0.023
#
# Uncorrected Low Phase:
# Mean Normal EW Low E/I: 0.52976
# Mean Normal EW Other:   0.59054
# Other/Low: 1.11473
#
# Corrected (tau=0.023) Low Phase:
# Mean Normal EW Low E/I: 0.63862
# Mean Normal EW Other:   0.63712
# Other/Low: 0.99767
#
# Overall change due to Tau:
# Mean Normal EW Low E/I: 1.20547
# Mean Normal EW Other:   1.07888
#
# Uncorrected H-G params:
#   g1 = 0.648 weight1 = 0.650
#   g2 = 0.016 weight2 = 0.350
#   Standard deviation: 0.05600
#
# Corrected (tau=0.023) params:
#   g1 = 0.638 weight1 = 0.660
#   g2 = -0.014 weight2 = 0.340
#   Standard deviation: 0.05304

# %%
print(region.capitalize()+' region, inner radius '+rin+', outer radius '+rout)
# Out:
# Core region, inner radius 139220, outer radius 141220

# %%
print(len(obsdata['Mean Phase'][~low_ei_mask]))
print(len(obsdata['Mean Phase'][low_ei_mask]))
# Out:
# 116
# 26
