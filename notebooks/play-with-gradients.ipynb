# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
if '..' not in sys.path: sys.path.append('..'); sys.path.append('../external')

from f_ring_util.f_ring import (add_hover,
                                read_ew_stats)

#%matplotlib notebook

# %%
obsdata = read_ew_stats('../data_files/cass_ew_0_0_moons.csv')
grads = pd.read_csv('../data_files/all_grads.csv', index_col='Observation')
obsdata = obsdata.join(grads, on='Observation', how='inner')
inner_obs = obsdata[obsdata['Suffix'] == 'inner']
plt.plot(inner_obs['Date'], inner_obs['Gradient Mean'])
# Out:
# ** SUMMARY STATISTICS - ../data_files/cass_ew_0_0_moons.csv **
# Unique observation names: 260
# Total slices: 260
# Starting date: 2004-06-20 19:15:28
# Ending date: 2017-09-07 21:22:03
# Time span: 4827 days 02:06:35

# %%
np.degrees(gravity.SATURN.n(140121.3, 0.00235))*86400
